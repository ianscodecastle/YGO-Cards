# %%
import requests
import pandas as pd

# %%
response = requests.get('https://db.ygoprodeck.com/api/v7/cardinfo.php')
data = response.json()['data']
# prices = response.json()['card_prices']

# %%
df = pd.DataFrame(data)
effect_monsters = df.loc[df['type']=='Effect Monster']
display(effect_monsters)
# Out:
#              id                        name            type  \
# 8      86988864              3-Hump Lacooda  Effect Monster
# 14     14261867            8-Claws Scorpion  Effect Monster
# 23     51351302            A Man with Wdjat  Effect Monster
# 28     13026402  A-Team: Trap Disposal Unit  Effect Monster
# 39     96146814                 A/D Changer  Effect Monster
# ...         ...                         ...             ...
# 11882   2648201          ZW - Sleipnir Mail  Effect Monster
# 11883  95886782           ZW - Sylphid Wing  Effect Monster
# 11884  81471108        ZW - Tornado Bringer  Effect Monster
# 11885  18865703        ZW - Ultimate Shield  Effect Monster
# 11886  76080032          ZW - Unicorn Spear  Effect Monster
#
#                                                     desc         race  \
# 8      If there are 3 face-up "3-Hump Lacooda" cards ...        Beast
# 14     Once per turn, you can flip this card into fac...       Insect
# 23     When you Normal Summon this card, and during e...  Spellcaster
# 28     This effect can be used during either player's...      Machine
# 39     You can banish this card from your Graveyard, ...      Warrior
# ...                                                  ...          ...
# 11882  You can target 1 "Utopia" monster you control;...        Beast
# 11883  You can only control 1 "ZW - Sylphid Wing". Yo...        Beast
# 11884  You can target 1 "Utopia" monster you control;...       Dragon
# 11885  When this card is Normal or Special Summoned: ...         Aqua
# 11886  You can target 1 "Number C39: Utopia Ray" you ...        Beast
#
#       archetype                                          card_sets  \
# 8           NaN  [{'set_name': 'Ancient Sanctuary', 'set_code':...
# 14          NaN  [{'set_name': 'Gold Series', 'set_code': 'GLD1...
# 23          NaN  [{'set_name': 'Dark Revelation Volume 1', 'set...
# 28          NaN  [{'set_name': 'Dark Revelation Volume 3', 'set...
# 39          NaN  [{'set_name': 'Duelist Pack: Yusei 3', 'set_co...
# ...         ...                                                ...
# 11882    Utopia  [{'set_name': 'Primal Origin', 'set_code': 'PR...
# 11883    Utopia  [{'set_name': 'Brothers of Legend', 'set_code'...
# 11884    Utopia  [{'set_name': 'Cosmo Blazer', 'set_code': 'CBL...
# 11885    Utopia  [{'set_name': 'Cosmo Blazer', 'set_code': 'CBL...
# 11886    Utopia  [{'set_name': 'Order of Chaos', 'set_code': 'O...
#
#                                              card_images  \
# 8      [{'id': 86988864, 'image_url': 'https://storag...
# 14     [{'id': 14261867, 'image_url': 'https://storag...
# 23     [{'id': 51351302, 'image_url': 'https://storag...
# 28     [{'id': 13026402, 'image_url': 'https://storag...
# 39     [{'id': 96146814, 'image_url': 'https://storag...
# ...                                                  ...
# 11882  [{'id': 2648201, 'image_url': 'https://storage...
# 11883  [{'id': 95886782, 'image_url': 'https://storag...
# 11884  [{'id': 81471108, 'image_url': 'https://storag...
# 11885  [{'id': 18865703, 'image_url': 'https://storag...
# 11886  [{'id': 76080032, 'image_url': 'https://storag...
#
#                                              card_prices     atk     def  \
# 8      [{'cardmarket_price': '0.08', 'tcgplayer_price...   500.0  1500.0
# 14     [{'cardmarket_price': '0.10', 'tcgplayer_price...   300.0   200.0
# 23     [{'cardmarket_price': '0.23', 'tcgplayer_price...  1600.0  1600.0
# 28     [{'cardmarket_price': '0.23', 'tcgplayer_price...   300.0   400.0
# 39     [{'cardmarket_price': '0.06', 'tcgplayer_price...   100.0   100.0
# ...                                                  ...     ...     ...
# 11882  [{'cardmarket_price': '0.06', 'tcgplayer_price...  1000.0  1000.0
# 11883  [{'cardmarket_price': '0.05', 'tcgplayer_price...   800.0  1600.0
# 11884  [{'cardmarket_price': '0.10', 'tcgplayer_price...  1300.0  1800.0
# 11885  [{'cardmarket_price': '0.06', 'tcgplayer_price...     0.0  2000.0
# 11886  [{'cardmarket_price': '0.07', 'tcgplayer_price...  1900.0     0.0
#
#        level attribute banlist_info  scale  linkval linkmarkers
# 8        3.0     EARTH          NaN    NaN      NaN         NaN
# 14       2.0      DARK          NaN    NaN      NaN         NaN
# 23       4.0      DARK          NaN    NaN      NaN         NaN
# 28       2.0      FIRE          NaN    NaN      NaN         NaN
# 39       1.0     LIGHT          NaN    NaN      NaN         NaN
# ...      ...       ...          ...    ...      ...         ...
# 11882    4.0     LIGHT          NaN    NaN      NaN         NaN
# 11883    4.0     LIGHT          NaN    NaN      NaN         NaN
# 11884    5.0      WIND          NaN    NaN      NaN         NaN
# 11885    4.0     EARTH          NaN    NaN      NaN         NaN
# 11886    4.0     LIGHT          NaN    NaN      NaN         NaN
#
# [4308 rows x 17 columns]
