# %%
import requests
import pandas as pd
import json

# %%
url = 'https://db.ygoprodeck.com/api/v7/cardinfo.php'
cards = requests.get(url=url)
cards_json = cards.json()['data']

# %%
# Make dataframe from json response
cards_df = pd.DataFrame(cards_json)

# Column of card names
cards_names = cards_df['name']

# Explode nested card prices column into its own dataframe
cards_prices = pd.json_normalize(cards_df['card_prices'].explode())

# Add names column to new prices dataframe, then reorder to put names first
cards_prices = cards_prices.join(cards_names)
price_cols = ['name','cardmarket_price', 'tcgplayer_price', 'ebay_price', 'amazon_price', 'coolstuffinc_price']
cards_prices = cards_prices[price_cols]

display(cards_prices)
# Out:
#                                 name cardmarket_price tcgplayer_price  \
# 0           "A" Cell Breeding Device             0.08            0.21
# 1                 "A" Cell Incubator             0.10            0.25
# 2      "A" Cell Recombination Device             0.17            0.27
# 3             "A" Cell Scatter Burst             0.09            0.19
# 4       "Infernoble Arms - Durendal"             0.19            0.22
# ...                              ...              ...             ...
# 11914             ZW - Sleipnir Mail             0.06            0.25
# 11915              ZW - Sylphid Wing             0.05            0.07
# 11916           ZW - Tornado Bringer             0.10            0.06
# 11917           ZW - Ultimate Shield             0.06            0.07
# 11918             ZW - Unicorn Spear             0.07            0.15
#
#       ebay_price amazon_price coolstuffinc_price
# 0           4.99         3.94               0.25
# 1           1.15         0.50               0.25
# 2           0.99         0.50               0.49
# 3           1.50         0.50               0.25
# 4           0.99         2.05               0.00
# ...          ...          ...                ...
# 11914       0.99         0.25               0.99
# 11915       0.99         0.55               0.99
# 11916       0.99         1.23               1.49
# 11917       0.99         0.20               0.49
# 11918       0.99         0.25               0.39
#
# [11919 rows x 6 columns]

# %%
import re
my_card = input()

result = cards_prices.loc[cards_prices['name'].str.contains(my_card, case=False)]

if result.empty:
    print(f'"{my_card}" was not found.')
else:
    display(result)
# Out:
#                                        name cardmarket_price tcgplayer_price  \
# 2356                          Dark Magician             0.08            0.56
# 2357                     Dark Magician Girl             0.11            0.40
# 2358   Dark Magician Girl the Dragon Knight             0.82            2.36
# 2359                   Dark Magician Knight             4.36            4.17
# 2360                 Dark Magician of Chaos             0.28            0.71
# 2361        Dark Magician the Dragon Knight             8.21           16.83
# 9322                  Skilled Dark Magician             0.08            0.31
# 10336                    The Dark Magicians            33.52           93.45
# 10671                    Toon Dark Magician             1.33            1.52
# 10672               Toon Dark Magician Girl             0.19            0.48
#
#       ebay_price amazon_price coolstuffinc_price
# 2356        3.99         4.00               5.99
# 2357        3.99         2.50              39.99
# 2358        4.95         6.74               2.99
# 2359        9.99        19.95               7.99
# 2360        9.95         4.54               0.79
# 2361        9.99        29.45              19.99
# 9322        0.99         1.14               0.79
# 10336     309.99       129.98              99.99
# 10671      15.95         1.47               1.99
# 10672       4.95         1.47              49.99

# %%
cards_images = pd.json_normalize(cards_df['card_images'].explode())
main_image = cards_images['image_url']

info_cols = ['name', 'level', 'attribute', 'type', 'race', 'archetype', 'atk', 'def', 'desc', 'image_url']
cards_info = cards_df.join(main_image)
cards_info = cards_info[info_cols]

cards_info
# Out:
#                                 name  level attribute            type  \
# 0           "A" Cell Breeding Device    NaN       NaN      Spell Card
# 1                 "A" Cell Incubator    NaN       NaN      Spell Card
# 2      "A" Cell Recombination Device    NaN       NaN      Spell Card
# 3             "A" Cell Scatter Burst    NaN       NaN      Spell Card
# 4       "Infernoble Arms - Durendal"    NaN       NaN      Spell Card
# ...                              ...    ...       ...             ...
# 11914             ZW - Sleipnir Mail    4.0     LIGHT  Effect Monster
# 11915              ZW - Sylphid Wing    4.0     LIGHT  Effect Monster
# 11916           ZW - Tornado Bringer    5.0      WIND  Effect Monster
# 11917           ZW - Ultimate Shield    4.0     EARTH  Effect Monster
# 11918             ZW - Unicorn Spear    4.0     LIGHT  Effect Monster
#
#              race     archetype     atk     def  \
# 0      Continuous         Alien     NaN     NaN
# 1      Continuous         Alien     NaN     NaN
# 2      Quick-Play         Alien     NaN     NaN
# 3      Quick-Play         Alien     NaN     NaN
# 4           Equip  Noble Knight     NaN     NaN
# ...           ...           ...     ...     ...
# 11914       Beast        Utopia  1000.0  1000.0
# 11915       Beast        Utopia   800.0  1600.0
# 11916      Dragon        Utopia  1300.0  1800.0
# 11917        Aqua        Utopia     0.0  2000.0
# 11918       Beast        Utopia  1900.0     0.0
#
#                                                     desc  \
# 0      During each of your Standby Phases, put 1 A-Co...
# 1      Each time an A-Counter(s) is removed from play...
# 2      Target 1 face-up monster on the field; send 1 ...
# 3      Select 1 face-up "Alien" monster you control. ...
# 4      While this card is equipped to a monster: You ...
# ...                                                  ...
# 11914  You can target 1 "Utopia" monster you control;...
# 11915  You can only control 1 "ZW - Sylphid Wing". Yo...
# 11916  You can target 1 "Utopia" monster you control;...
# 11917  When this card is Normal or Special Summoned: ...
# 11918  You can target 1 "Number C39: Utopia Ray" you ...
#
#                                                image_url
# 0      https://storage.googleapis.com/ygoprodeck.com/...
# 1      https://storage.googleapis.com/ygoprodeck.com/...
# 2      https://storage.googleapis.com/ygoprodeck.com/...
# 3      https://storage.googleapis.com/ygoprodeck.com/...
# 4      https://storage.googleapis.com/ygoprodeck.com/...
# ...                                                  ...
# 11914  https://storage.googleapis.com/ygoprodeck.com/...
# 11915  https://storage.googleapis.com/ygoprodeck.com/...
# 11916  https://storage.googleapis.com/ygoprodeck.com/...
# 11917  https://storage.googleapis.com/ygoprodeck.com/...
# 11918  https://storage.googleapis.com/ygoprodeck.com/...
#
# [11919 rows x 10 columns]

# %%
my_card = input()

result = cards_info.loc[cards_info['name'].str.contains(my_card, case=False)]

if result.empty:
    print(f'"{my_card}" was not found.')
else:
    display(result)
# Out:
#         name  level attribute            type   race archetype     atk    def  \
# 8928  Sangan    3.0      DARK  Effect Monster  Fiend       NaN  1000.0  600.0
#
#                                                    desc  \
# 8928  If this card is sent from the field to the GY:...
#
#                                               image_url
# 8928  https://storage.googleapis.com/ygoprodeck.com/...
